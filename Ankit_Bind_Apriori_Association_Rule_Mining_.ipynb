# %% [markdown]
# # **Apriori- Association Rule Mining**

# %%
import pandas as pd
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df = pd.read_csv("/kaggle/AnimeWorld.csv")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                                Anime  \
# 0   Re:Zero kara Hajimeru Isekai Seikatsu 2nd Season
# 1                               Kanojo, Okarishimasu
# 2                             The God of High School
# 3  Maou Gakuin no Futekigousha: Shijou Saikyou no...
# 4                     Enen no Shouboutai: Ni no Shou
#
#                                              Genre  \
# 0                 ['Drama', 'Fantasy', 'Suspense']
# 1                            ['Comedy', 'Romance']
# 2  ['Action', 'Fantasy', 'Sci-Fi', 'Supernatural']
# 3                            ['Action', 'Fantasy']
# ...

# %%
df.values #values of each row
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array([['Re:Zero kara Hajimeru Isekai Seikatsu 2nd Season',
#         "['Drama', 'Fantasy', 'Suspense']",
# ...

# %%
df.shape # shape of the dataframe.
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (2981, 6)

# %%
# !pip install mlxtend #for using mlextend library you have to run this cell.
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ...

# %%
df.columns #showing column names
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Index(['Anime', 'Genre', 'Description', 'Studio', 'Year', 'Rating'], dtype='object')

# %%
data = list(df["Genre"].apply(lambda x:x.split(',')))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [["['Drama'", " 'Fantasy'", " 'Suspense']"],
#  ["['Comedy'", " 'Romance']"],
#  ["['Action'", " 'Fantasy'", " 'Sci-Fi'", " 'Supernatural']"],
#  ["['Action'", " 'Fantasy']"],
#  ["['Action'", " 'Supernatural']"],
#  ["['Comedy'", " 'Romance']"],
#  ["['Action'", " 'Adventure'", " 'Mystery']"],
#  ["['Action'", " 'Adventure'", " 'Fantasy']"],
#  ["['Comedy'", " 'Ecchi']"],
#  ["['Action'", " 'Adventure'", " 'Sci-Fi']"],
#  ["['Comedy'", " 'Fantasy'", " 'Romance'", " 'Ecchi']"],
#  ["['Comedy'", " 'Fantasy'", " 'Ecchi']"],
#  ["['Action'", " 'Comedy'", " 'Supernatural'", " 'Ecchi']"],
#  ["['Action'", " 'Drama'", " 'Sci-Fi']"],
# ...

# %%
from mlxtend.preprocessing import TransactionEncoder
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
te = TransactionEncoder()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
te_data = te.fit(data).transform(data)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df = pd.DataFrame(te_data,columns=te.columns_)
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        'Adventure'   'Adventure']   'Boys Love'   'Comedy'   'Comedy']  \
# 0            False          False         False      False       False
# 1            False          False         False      False       False
# 2            False          False         False      False       False
# 3            False          False         False      False       False
# 4            False          False         False      False       False
# ...            ...            ...           ...        ...         ...
# 2976         False          False         False      False       False
# ...

# %%
te_data
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
pip install apyori
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ...

# %%
from mlxtend.frequent_patterns import apriori
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df1 = apriori(df,min_support=0.1,use_colnames=True)
df1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     support             itemsets
# 0  0.113049          ( 'Comedy')
# 1  0.100302           ( 'Drama')
# 2  0.100302         ( 'Fantasy')
# 3  0.102650        ( 'Fantasy'])
# 4  0.134854         ( 'Sci-Fi'])
# 5  0.120094  ( 'Slice of Life'])
# 6  0.123113   ( 'Supernatural'])
# 7  0.100973             (Comedy)
# 8  0.293190          (['Action')
# 9  0.247232          (['Comedy')

# %%
df1.sort_values(by="support",ascending=False)#sorting operation
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     support             itemsets
# 8  0.293190          (['Action')
# 9  0.247232          (['Comedy')
# 4  0.134854         ( 'Sci-Fi'])
# 6  0.123113   ( 'Supernatural'])
# 5  0.120094  ( 'Slice of Life'])
# 0  0.113049          ( 'Comedy')
# 3  0.102650        ( 'Fantasy'])
# 7  0.100973             (Comedy)
# 1  0.100302           ( 'Drama')
# 2  0.100302         ( 'Fantasy')

# %%
df1['length'] = df1['itemsets'].apply(lambda x:len(x))#add length column to a dataframe
df1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     support             itemsets  length
# 0  0.113049          ( 'Comedy')       1
# 1  0.100302           ( 'Drama')       1
# 2  0.100302         ( 'Fantasy')       1
# 3  0.102650        ( 'Fantasy'])       1
# 4  0.134854         ( 'Sci-Fi'])       1
# 5  0.120094  ( 'Slice of Life'])       1
# 6  0.123113   ( 'Supernatural'])       1
# 7  0.100973             (Comedy)       1
# 8  0.293190          (['Action')       1
# 9  0.247232          (['Comedy')       1

# %%
min_confidence_threshold = 0.1
  # Start with a low value to ensure rules are generated
rules = association_rules(df1, metric="confidence", min_threshold=min_confidence_threshold)
if rules.empty:
  print(f"No rules meet the minimum confidence threshold of {min_confidence_threshold}.")
else:
   print("Association Rules:\n", rules)

        # Inspect the support, confidence, and lift of the generated rules
print("Support, Confidence, and Lift of Rules:\n", rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])

        # Check the first few rules for verification
print(rules.head())
# Out:
# No rules meet the minimum confidence threshold of 0.1.
# Support, Confidence, and Lift of Rules:
#  Empty DataFrame
# Columns: [antecedents, consequents, support, confidence, lift]
# Index: []
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric]
# Index: []
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
